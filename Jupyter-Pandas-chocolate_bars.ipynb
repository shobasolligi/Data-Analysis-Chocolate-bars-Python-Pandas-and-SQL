# %%
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\Shoba'

# %%
oo=pd.read_csv('C:\\Users\\Shoba\\chocolate_bars.csv',engine='python')
oo.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %%
oo.groupby('year_reviewed')

# %%
oo.groupby('year_reviewed').size()
# Out:
# year_reviewed
# 2006     62
# 2007     73
# 2008     92
# 2009    123
# 2010    110
# 2011    163
# 2012    194
# 2013    183
# 2014    247
# 2015    284
# 2016    217
# 2017    105
# 2018    228
# 2019    193
# 2020     81
# 2021    175
# dtype: int64

# %%
oo.groupby('year_reviewed').size().plot()
# Out:
# <AxesSubplot:xlabel='year_reviewed'>

# %%
oo.groupby('rating').size()
# Out:
# rating
# 1.00      4
# 1.50     10
# 1.75      3
# 2.00     33
# 2.25     17
# 2.50    166
# 2.75    333
# 3.00    523
# 3.25    464
# 3.50    565
# 3.75    300
# 4.00    112
# dtype: int64

# %%
oo.groupby('rating').size().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
usa=oo[oo.company_location=='U.S.A']
usa
# Out:
# Empty DataFrame
# Columns: [id, manufacturer, company_location, year_reviewed, bean_origin, bar_name, cocoa_percent, num_ingredients, ingredients, review, rating]
# Index: []

# %%
oo[(oo.company_location=='U.S.A')]
# Out:
# Empty DataFrame
# Columns: [id, manufacturer, company_location, year_reviewed, bean_origin, bar_name, cocoa_percent, num_ingredients, ingredients, review, rating]
# Index: []

# %%
# USA has the highest location of chacolates

oo.groupby('company_location').size()
# Out:
# company_location
# Amsterdam      12
# Argentina       9
# Australia      53
# Austria        30
# Belgium        63
#              ...
# U.S.A.       1136
# Vanuatu         4
# Venezuela      31
# Vietnam        16
# Wales           1
# Length: 67, dtype: int64

# %%
## listing of headers from dataframe
list(oo[oo.company_location=='U.S,A'])
# Out:
# ['id',
#  'manufacturer',
#  'company_location',
#  'year_reviewed',
#  'bean_origin',
#  'bar_name',
#  'cocoa_percent',
#  'num_ingredients',
#  'ingredients',
#  'review',
#  'rating']

# %%
oo.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %%
# how to have groupby, sort by with values

so=oo.groupby('company_location').size().sort_values(ascending=False)
so.head(10).plot(kind='bar',color='Red')
# Out:
# <AxesSubplot:xlabel='company_location'>

# %%
## USA highest ratings are between 3-3.75 rating with group by two clauses
lo=oo.groupby(['company_location','rating']).size().sort_values(ascending=False)
lo.head(15).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='company_location,rating'>

# %%
## Pie plot below
lo=oo.groupby(['company_location','rating']).size().sort_values(ascending=False)
lo.head(10).plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
oo.head()
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
#
#                  bar_name  cocoa_percent  num_ingredients ingredients  \
# 0   Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# 1         Zorzal, batch 1           76.0              3.0       B,S,C
# 2  Bejofo Estate, batch 1           76.0              3.0       B,S,C
# 3   Matasawalevu, batch 1           68.0              3.0       B,S,C
# 4   Sur del Lago, batch 1           72.0              3.0       B,S,C
#
#                               review  rating
# 0          rich cocoa, fatty, bready    3.25
# ...

# %%
to=oo[(oo.company_location=='U.S.A.')]
to
# Out:
#         id manufacturer company_location  year_reviewed         bean_origin  \
# 0     2454         5150           U.S.A.           2019            Tanzania
# 1     2458         5150           U.S.A.           2019  Dominican Republic
# 2     2454         5150           U.S.A.           2019          Madagascar
# 3     2542         5150           U.S.A.           2021                Fiji
# 4     2546         5150           U.S.A.           2021           Venezuela
# ...    ...          ...              ...            ...                 ...
# 2489  1582        Zak's           U.S.A.           2015               Blend
# 2490  1578        Zak's           U.S.A.           2015  Dominican Republic
# 2491  1578        Zak's           U.S.A.           2015          Madagascar
# 2492  1578        Zak's           U.S.A.           2015                Peru
# 2493  1578        Zak's           U.S.A.           2015              Belize
#
# ...

# %%
to=oo[(oo.company_location=='U.S.A.')&('rating'==3.0)]
to
# Out:
# Empty DataFrame
# Columns: [id, manufacturer, company_location, year_reviewed, bean_origin, bar_name, cocoa_percent, num_ingredients, ingredients, review, rating]
# Index: []

# %%
print(oo.dtypes)
# Out:
# id                    int64
# manufacturer         object
# company_location     object
# year_reviewed         int64
# bean_origin          object
# bar_name             object
# cocoa_percent       float64
# num_ingredients     float64
# ingredients          object
# review               object
# rating              float64
# dtype: object

# %%
oo.head(10)
# Out:
#      id manufacturer company_location  year_reviewed         bean_origin  \
# 0  2454         5150           U.S.A.           2019            Tanzania
# 1  2458         5150           U.S.A.           2019  Dominican Republic
# 2  2454         5150           U.S.A.           2019          Madagascar
# 3  2542         5150           U.S.A.           2021                Fiji
# 4  2546         5150           U.S.A.           2021           Venezuela
# 5  2546         5150           U.S.A.           2021              Uganda
# 6  2542         5150           U.S.A.           2021               India
# 7   797     A. Morin           France           2012             Bolivia
# 8   797     A. Morin           France           2012                Peru
# 9  1011     A. Morin           France           2013              Panama
#
#                    bar_name  cocoa_percent  num_ingredients ingredients  \
# 0     Kokoa Kamili, batch 1           76.0              3.0       B,S,C
# ...

# %%
avg=oo.groupby(['bean_origin','rating'])[['cocoa_percent']].mean()
avg.sort_values('cocoa_percent',ascending=False).head(10)
# Out:
#                     cocoa_percent
# bean_origin rating
# Venezuela   1.75       100.000000
# Indonesia   2.25       100.000000
# Samoa       2.75       100.000000
# St. Lucia   1.75       100.000000
# Ecuador     1.50        97.000000
#             2.00        86.166667
# Blend       1.50        84.000000
#             1.00        81.000000
# Fiji        3.50        80.000000
#             3.75        80.000000

# %%
avg=oo.groupby(['bean_origin'])[['cocoa_percent']].mean()
avg.sort_values('cocoa_percent',ascending=True).head(10)
# Out:
#              cocoa_percent
# bean_origin
# Martinique       42.000000
# Tobago           65.000000
# Sulawesi         66.000000
# DR Congo         68.000000
# Puerto Rico      68.285714
# Nigeria          68.333333
# Australia        69.000000
# U.S.A.           69.242424
# Cameroon         69.333333
# Grenada          69.368421

# %%
avg=oo.groupby(['bean_origin','cocoa_percent'])[['rating']].mean()
avg.sort_values('rating',ascending=False).head(10)
# Out:
#                                rating
# bean_origin     cocoa_percent
# Tobago          70.0             4.00
# Peru            63.0             3.80
# Australia       67.0             3.75
# Solomon Islands 67.0             3.75
# Blend           73.5             3.75
# Ecuador         78.0             3.75
# Indonesia       69.0             3.75
# Blend           90.0             3.75
# Trinidad        67.0             3.75
# Bolivia         66.0             3.75
